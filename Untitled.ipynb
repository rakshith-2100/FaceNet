# %%
# !pip install facenet_pytorch
# Out:
# Requirement already satisfied: facenet_pytorch in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (2.5.3)
# Requirement already satisfied: numpy in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from facenet_pytorch) (1.23.5)
# Requirement already satisfied: requests in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from facenet_pytorch) (2.28.2)
# Requirement already satisfied: torchvision in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from facenet_pytorch) (0.15.2)
# Requirement already satisfied: pillow in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from facenet_pytorch) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from requests->facenet_pytorch) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from requests->facenet_pytorch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from requests->facenet_pytorch) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from requests->facenet_pytorch) (2022.12.7)
# Requirement already satisfied: torch==2.0.1 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torchvision->facenet_pytorch) (2.0.1+cu118)
# Requirement already satisfied: filelock in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.12.0)
# Requirement already satisfied: typing-extensions in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision->facenet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision->facenet_pytorch) (1.12)
# Requirement already satisfied: networkx in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision->facenet_pytorch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch==2.0.1->torchvision->facenet_pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mr_x\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch==2.0.1->torchvision->facenet_pytorch) (1.3.0)

# %%
from facenet_pytorch import MTCNN, InceptionResnetV1
import torch
import numpy as np
from torchvision import datasets
from torch.utils.data import DataLoader
from PIL import Image
import cv2
import time
import os

# %%
mtcnn0 = MTCNN(image_size=240, margin=0, keep_all=False, min_face_size=40) # keep_all=False
mtcnn = MTCNN(image_size=240, margin=0, keep_all=True, min_face_size=40) # keep_all=True
resnet = InceptionResnetV1(pretrained='vggface2').eval()

# %%
dataset = datasets.ImageFolder('photos') # photos folder path 
idx_to_class = {i:c for c,i in dataset.class_to_idx.items()} # accessing names of peoples from folder names

def collate_fn(x):
    return x[0]

loader = DataLoader(dataset, collate_fn=collate_fn)

name_list = [] # list of names corrospoing to cropped photos
embedding_list = [] # list of embeding matrix after conversion from cropped faces to embedding matrix using resnet

for img, idx in loader:
    face, prob = mtcnn0(img, return_prob=True) 
    if face is not None and prob>0.92:
        emb = resnet(face.unsqueeze(0)) 
        embedding_list.append(emb.detach()) 
        name_list.append(idx_to_class[idx])        

# save data
data = [embedding_list, name_list] 
torch.save(data, 'data.pt')

# %%
# Using webcam recognize face

# loading data.pt file
load_data = torch.load('data.pt') 
embedding_list = load_data[0] 
name_list = load_data[1] 

cam = cv2.VideoCapture(0) 

while True:
    ret, frame = cam.read()
    if not ret:
        print("fail to grab frame, try again")
        break
        
    img = Image.fromarray(frame)
    img_cropped_list, prob_list = mtcnn(img, return_prob=True) 
    
    if img_cropped_list is not None:
        boxes, _ = mtcnn.detect(img)
                
        for i, prob in enumerate(prob_list):
            if prob>0.90:
                emb = resnet(img_cropped_list[i].unsqueeze(0)).detach() 
                
                dist_list = []
                
                for idx, emb_db in enumerate(embedding_list):
                    dist = torch.dist(emb, emb_db).item()
                    dist_list.append(dist)
                Min=np.array(dist_list)<1.05
                dist_list=dist_list*Min
                names=np.where(Min,name_list,'')
                names=names[names!='']
                print(f'Name:{names}')
                box = boxes[i] 
                
                original_frame = frame.copy()

    cv2.imshow("IMG", frame)
        
    
    k = cv2.waitKey(1)
    if k%256==27: # ESC
        print('Esc pressed, closing...')
        break
        
    elif k%256==32: # space to save image
        print('Enter your name :')
        name = input()
        
        # create directory if not exists
        if not os.path.exists('photos/'+name):
            os.mkdir('photos/'+name)
            
        img_name = "photos/{}/{}.jpg".format(name, int(time.time()))
        cv2.imwrite(img_name, original_frame)
        print(" saved: {}".format(img_name))
        
print(names)        
cam.release()
cv2.destroyAllWindows()
# Out:
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:[]
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['BillGates']
# Name:['BillGates']
# Name:['BillGates']
# Name:['BillGates']
# Name:['BillGates']
# Name:[]
# Name:['BillGates']
# Name:['Rakshith']
# Name:['BillGates']
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:['BillGates']
# Name:['BillGates']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith' 'Virat']
# Name:['Rakshith' 'Virat']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['ronaldo']
# Name:['ronaldo']
# Name:[]
# Name:[]
# Name:[]
# Name:['ronaldo']
# Name:['ronaldo']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['ronaldo']
# Name:['Rakshith' 'ronaldo']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:['Rakshith']
# Name:[]
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:['Rakshith']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:[]
# Name:[]
# Name:[]
# Name:['Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:[]
# Name:['Elon']
# Name:[]
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:[]
# Name:[]
# Name:[]
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon']
# Name:[]
# Name:[]
# Name:[]
# Name:['Elon' 'Jeff Bejos']
# Name:[]
# Name:['Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon' 'Jeff Bejos']
# Name:['Elon']
# Name:['Elon']
# Name:['Elon' 'Jeff Bejos']
